# %% [markdown]
# <a href="https://colab.research.google.com/github/pranitakhade/The_Sparks_Foundation_Internship/blob/main/GRIP_Task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project By-
# #Pranit Akhade

# %% [markdown]
# ## Task 3 - Perform EDA on Dataset 'SampleSuperstore'
#
# Perform 'Exploratory Data Analysis' on Dataset 'SampleSuperstore'. As a business manager, try to find out the weak areas where you can work to make more profits.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/SampleSuperstore.csv")

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 17

# %%
data.drop_duplicates(keep='first',inplace=True)

# %%
data.shape
# Out:
# (9977, 13)

# %%
data['Profit_Percentage'] = (data['Profit'] / data['Sales'])*100

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit  Profit_Percentage
# 0      0.00   41.9136              16.00
# ...

# %%
data.describe(include='all')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9977      9977           9977           9977        9977
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5955      5183           9977            914        1996
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
# ...

# %%
sns.countplot(data=data, x='Ship Mode')
plt.show()

# %%
plt.figure(figsize=(8,8))
data['Sub-Category'].value_counts().plot.pie(autopct='%.2f')

plt.tight_layout()
plt.show()

# %%
sns.lineplot(data = data , x ='Discount', y='Profit')
plt.title('Profits Vs Discount')
plt.show()

# %%
sns.lineplot(data = data , x ='Quantity', y='Profit')
plt.title('Profits Vs Quantity')
plt.show()

# %%
best_category = data.groupby(['Category'])[['Sales', 'Quantity', 'Profit']].sum().reset_index()
best_category
# Out:
#           Category        Sales  Quantity       Profit
# 0        Furniture  741306.3133      8020   18421.8137
# 1  Office Supplies  718735.2440     22861  122364.6608
# 2       Technology  836154.0330      6939  145454.9481

# %%
# Create a figure with three subplots in a single row
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot the first bar plot
sns.barplot(data=best_category, x='Category', y='Sales', ax=axes[0])
axes[0].set_title('Sales')

# Plot the second bar plot
sns.barplot(data=best_category, x='Category', y='Quantity', ax=axes[1])
axes[1].set_title('Quantity')

# Plot the third bar plot
sns.barplot(data=best_category, x='Category', y='Profit', ax=axes[2])
axes[2].set_title('Profit')

# Adjust layout to prevent clipping of titles
plt.tight_layout()

# Show the plots
plt.show()

# %%
best_sub_category = data.groupby(['Sub-Category'])[['Sales','Quantity','Profit']].sum().reset_index()
best_sub_category
# Out:
#    Sub-Category        Sales  Quantity      Profit
# 0   Accessories  167380.3180      2976  41936.6357
# 1    Appliances  107532.1610      1729  18138.0054
# 2           Art   27107.0320      2996   6524.6118
# 3       Binders  203409.1690      5971  30228.0003
# 4     Bookcases  114879.9963       868  -3472.5560
# 5        Chairs  327777.7610      2351  26567.1278
# 6       Copiers  149528.0300       234  55617.8249
# 7     Envelopes   16476.4020       906   6964.1767
# 8     Fasteners    3024.2800       914    949.5182
# 9   Furnishings   91683.0240      3560  13052.7230
# 10       Labels   12444.9120      1396   5526.3820
# 11     Machines  189238.6310       440   3384.7569
# 12        Paper   78224.1420      5144  33944.2395
# 13       Phones  330007.0540      3289  44515.7306
# 14      Storage  223843.6080      3158  21278.8264
# 15     Supplies   46673.5380       647  -1189.0995
# 16       Tables  206965.5320      1241 -17725.4811

# %%
fig, axes = plt.subplots(1, 2, figsize = [15, 6])

sns.barplot(data= best_sub_category, x = 'Sub-Category', y = 'Sales', ax = axes[0])
axes[0].set_title('Sales')
axes[0].tick_params(axis='x', rotation=90)

sns.barplot(data= best_sub_category, x = 'Sub-Category', y = 'Profit', ax = axes[1])
axes[1].set_title('Profit')
axes[1].tick_params(axis='x', rotation=90)

plt.tight_layout()

plt.show()

# %%
sns.barplot(data=best_sub_category.sort_values(by='Quantity', ascending=False), x = 'Sub-Category', y = 'Quantity')
plt.xticks(rotation = 90)
plt.show()

# %%
best_segment = data.groupby(['Segment'])['Profit'].sum().reset_index()
best_segment
# Out:
#        Segment       Profit
# 0     Consumer  134007.4413
# 1    Corporate   91954.9798
# 2  Home Office   60279.0015

# %%
sns.barplot(data=best_segment, x ='Segment', y = 'Profit')
plt.show()

# %%
best_region = data.groupby(['Region'])['Profit'].sum().reset_index()
best_region
# Out:
#     Region       Profit
# 0  Central   39655.8752
# 1     East   91506.3092
# 2    South   46749.4303
# 3     West  108329.8079

# %%
plt.pie(best_region['Profit'],labels = best_region['Region'], autopct = '%.2f')
plt.title("Most Profitable by Region")
plt.show()

# %%
best_city = data.groupby(['City'])['Sales'].sum().reset_index().sort_values(by='Sales', ascending=False)
top10 = best_city[:10]
bottom10 = best_city[-10:]
best_city
# Out:
#               City       Sales
# 329  New York City  256319.041
# 266    Los Angeles  175831.901
# 452        Seattle  119460.282
# 438  San Francisco  112577.172
# 374   Philadelphia  109061.461
# ..             ...         ...
# 354   Ormond Beach       2.808
# 370      Pensacola       2.214
# 221        Jupiter       2.064
# 140         Elyria       1.824
# 1          Abilene       1.392
#
# [531 rows x 2 columns]

# %%
fig, axes = plt.subplots(1, 2, figsize = [10,5])

sns.barplot(data = top10, x = 'City', y='Sales', ax = axes[0])
axes[0].tick_params(axis = 'x', rotation = 90)
axes[0].set_title('Top 10 City with Highest Sales')

sns.barplot(data = bottom10.sort_values(by = 'Sales', ascending = False), x = 'City', y='Sales', ax = axes[1])
axes[1].tick_params(axis = 'x', rotation = 90)
axes[1].set_title('Top 10 City with Lowest Sales')

plt.tight_layout()

plt.show()
